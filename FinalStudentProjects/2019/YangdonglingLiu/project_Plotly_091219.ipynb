# %%
import plotly.express as px
import plotly.offline as pyo
import plotly.graph_objects as po

pyo.init_notebook_mode()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-187adf20c34b> in <module>
# ----> 1 import plotly.express as px
#       2 import plotly.offline as pyo
#       3 import plotly.graph_objects as po
#       4
#       5 pyo.init_notebook_mode()
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/AMST3_SepOct.csv")
df
# Out:
#          Time start      Time stop   Organic   Sulfate  Ammonium   Nitrate  \
# 0     9/13/14 13:52  9/13/14 13:55  11.89850  1.456710  0.436832  0.313269
# 1     9/13/14 17:45  9/13/14 17:47  11.94720  1.758410  0.550953  0.290176
# 2     9/13/14 17:53  9/13/14 17:55  11.20270  1.590140  0.515114  0.211021
# 3     9/13/14 18:01  9/13/14 18:03  10.73810  1.484200  0.456858  0.174378
# 4     9/13/14 18:09  9/13/14 18:11  11.26250  1.562690  0.477693  0.174844
# 5     9/13/14 18:17  9/13/14 18:19  11.69100  1.582690  0.503957  0.194480
# 6     9/13/14 18:25  9/13/14 18:27  11.38780  1.580270  0.510905  0.164823
# 7     9/13/14 18:33  9/13/14 18:35  10.95210  1.450210  0.453779  0.162619
# 8     9/13/14 18:41  9/13/14 18:43  10.92600  1.433650  0.476453  0.152684
# 9     9/13/14 18:49  9/13/14 18:51   3.88525  0.595637  0.171677  0.038497
# 10    9/13/14 18:57  9/13/14 18:59   3.55995  0.596208  0.174129  0.047259
# ...

# %%
df_part = df[['Time stop', 'Organic', 'Sulfate', 'Ammonium', 'Nitrate', 'Chloride']]
df_part
# Out:
#           Time stop   Organic   Sulfate  Ammonium   Nitrate  Chloride
# 0     9/13/14 13:55  11.89850  1.456710  0.436832  0.313269  0.013822
# 1     9/13/14 17:47  11.94720  1.758410  0.550953  0.290176  0.015616
# 2     9/13/14 17:55  11.20270  1.590140  0.515114  0.211021  0.013689
# 3     9/13/14 18:03  10.73810  1.484200  0.456858  0.174378  0.014700
# 4     9/13/14 18:11  11.26250  1.562690  0.477693  0.174844  0.017399
# 5     9/13/14 18:19  11.69100  1.582690  0.503957  0.194480  0.016549
# 6     9/13/14 18:27  11.38780  1.580270  0.510905  0.164823  0.018170
# 7     9/13/14 18:35  10.95210  1.450210  0.453779  0.162619  0.008872
# 8     9/13/14 18:43  10.92600  1.433650  0.476453  0.152684  0.016209
# 9     9/13/14 18:51   3.88525  0.595637  0.171677  0.038497  0.009524
# 10    9/13/14 18:59   3.55995  0.596208  0.174129  0.047259  0.009437
# 11    9/13/14 19:07   5.94130  0.900445  0.284233  0.046628  0.010277
# ...

# %%
fig = px.scatter_matrix(df_part)
#fig.show()
#fig.data
fig.update_traces(marker=dict(size=2,opacity=0.5, color='black'))
# Out:
# <div>
#
#
#             <div id="4585f85e-5e86-42e3-ae80-392100314e79" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("4585f85e-5e86-42e3-ae80-392100314e79")) {
#                     Plotly.newPlot(
#                         '4585f85e-5e86-42e3-ae80-392100314e79',
# ...
