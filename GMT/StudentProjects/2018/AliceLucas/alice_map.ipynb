# %%
import gmt

# %%
fig = gmt.Figure()
fig.coast(region=[-5, -2, 47, 49], projection='M6i', S = 'blue', land='chocolate', rivers = '1',
          frame=True)

#grid = gmt.datasets.load_earth_relief(resolution="10m")
#fig.grdimage(grid, cmap="geo")

fig.plot(x=[-4.46275],y=[47.9857], sizes = [0.5], style='cc', color='white')
fig.show()
