# %%
import gmt

# %%
fig=gmt.Figure()

# %%
fig.basemap(region=[65,135,15,55],J='M9i',frame=True)
fig.grdimage("@earth_relief_10m",cmap='geo',shading=True)
fig.plot(x=[99,116.4],y=[31,39.9],style="a0.2i", color="black", pen="black")
#fig.logo(region=[75,85,30,40],J='M9i')
fig.show()
# Out:
# gmt-python-session [ERROR]: Current panel has row or column outsiden range!
# gmt-python-session [ERROR]: Current panel has row or column outsiden range!
# gmt-python-session [ERROR]: Current panel has row or column outsiden range!

# %%
fig.show()
