# %% [markdown]
# # Convert OpenSN data to name,host,type,x,y,z,t,lum
#
# Data downloaded from The Open Supernova Catalog https://sne.space on Aug. 20, 2019

# %%
import pandas as pd
import numpy as np
from astropy import units
from astropy.coordinates import SkyCoord, Distance
from astropy.cosmology import WMAP9
import datetime

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('OpenSNCat.csv')
#select the ones that have all the data we need
#In the end, I want z, but sonce there are multiple z values for some sources, 
# I think I will just use the luminosity distance and convert below
df = df.loc[(df['R.A.'].notnull()) & \
              (df['Dec.'].notnull()) & \
              (df['dL (Mpc)'].notnull()) & \
              (df['Disc. Date'].notnull()) & \
              (df['Mmax'].notnull())]
df
# Out:
#                           Name  Disc. Date     Mmax                 Host Name  \
# 0                      SN1987A  1987/02/24 -16.3000                       LMC
# 1                     SN2011fe  2011/08/24 -18.2800                  NGC 5457
# 2                     SN2003dh  2003/03/31 -26.8230              A104450+2131
# 3      CSS141118:092034+504148  2016/04/22 -19.3000  SDSS J092034.44+504148.7
# 4                      SN1993J  1993/03/28 -17.4000                  NGC 3031
# 5                     SN2012fr  2012/10/27 -20.2000                  NGC 1365
# 6                     SN2002ap  2002/01/29 -17.8100                   NGC 628
# 7                     SN2013dy  2013/07/10 -18.3810                  NGC 7250
# 8                     SN2009ip  2012/07/24 -20.0940                  NGC 7259
# 9                     SN2011dh  2011/06/01 -18.1520                  NGC 5194
# 10                    SN2013ej  2013/07/25 -18.3800                   NGC 628
# 11                    SN2012dn  2012/07/08 -19.6060               ESO 462-G16
# 12                    SN2012aw  2012/03/16 -18.3420                  NGC 3351
# 13                    SN1999ee  1999/10/07 -18.6000                   IC 5179
# 14                    SN2000cx  2000/07/17 -19.3000                   NGC 524
# 15                     SN2014J  2014/01/21 -18.4000                  NGC 3034
# 16                    SN1999em  1999/10/29 -16.6000                  NGC 1637
# 17                    SN2005cf  2005/05/28 -18.7000             MCG -01-39-03
# 18                    SN1998bu  1998/05/09 -18.5000                  NGC 3368
# 20                 ASASSN-14ha  2014/09/10 -19.5050                  NGC 1566
# 21                    SN2007af  2007/03/01 -18.3000                  NGC 5584
# 22                    SN2010jl  2010/11/03 -22.8000                 UGC 5189A
# 23                    SN2015bn  2015/02/15 -22.8740  SDSS J113341.53+004333.2
# 25                    PTF12hsx  2012/08/14 -17.2000  SDSS J005503.33+421954.0
# 26                   SN2016bkv  2016/03/21 -16.0000                  NGC 3184
# 27                     SN2015F  2015/03/09 -18.8000                  NGC 2442
# 28                   SN2016bln  2016/04/04 -19.7779                  NGC 5221
# 29                    SN2009dc  2009/04/09 -20.3820                 UGC 10064
# 30                   SN2016dxj  2016/04/16 -22.4000                       NaN
# 32                    SN2005bf  2005/04/05 -19.2644             MCG +00-27-05
# ...                        ...         ...      ...                       ...
# 57637                PS1-10cbs        2010 -19.5000                       NaN
# 57665                 PS1-10iv  2010/05/04 -19.7300                       NaN
# 57671                 PS1-10lb        2010 -20.0000                       NaN
# 57672                 PS1-10lh        2010 -19.0000                       NaN
# 57673                 PS1-10lp        2010 -19.5000                       NaN
# 57674                 PS1-10ls        2010 -19.1000                       NaN
# 57676                 PS1-10lw        2010 -20.0000                       NaN
# 57679                 PS1-10mi        2010 -18.7000                       NaN
# 57682                 PS1-10nf        2010 -19.2000                       NaN
# 57684                 PS1-10np        2010 -19.5000                       NaN
# 57685                 PS1-10qu        2010 -19.1000                       NaN
# 57686                 PS1-10qv        2010 -19.6000                       NaN
# 57687                 PS1-10rj        2010 -19.0000                       NaN
# 57692                 PS1-10tb        2010 -19.4000                       NaN
# 57695                 PS1-10uu        2010 -19.0000                       NaN
# 57699                 PS1-10wb        2010 -20.0000                       NaN
# 57701                 PS1-10wn        2010 -19.1000                       NaN
# 57702                 PS1-10xc        2010 -19.3000                       NaN
# 57703                 PS1-10xe        2010 -19.0000                       NaN
# 57709                 PS1-10zo        2010 -20.0000                       NaN
# 57714                 PS1-10zz        2010 -18.4000                       NaN
# 57719                 PS1-11ad        2011 -20.5700                       NaN
# 57767                 PS1-11bp        2011 -19.9000                       NaN
# 57768                 PS1-11bw        2011 -19.5000                       NaN
# 57774                 PS1-11du        2011 -18.8000                       NaN
# 57778                 PS1-11ex        2011 -19.0000                       NaN
# 57812                  PS1-11r        2011 -19.0000                       NaN
# 57842                 PS1-11yh  2011/05/24 -17.9300                       NaN
# 63595                   SN185A   185/12/07 -16.0000                 Milky Way
# 63607                   SN393A   393/02/27 -11.0000                 Milky Way
#
#                                                     R.A.  \
# 0      05:35:28.020,05:35:28,05:35:28.01,05:35:27.989...
# 1      14:03:05.711,14:03:05.76,14:03:05.81,14:03:05....
# 2      10:44:50.030,10:44:50.01,10:44:50.009,10:44:50...
# 3       09:20:34.300,09:20:34.38,09:20:34.26,09:20:34.32
# 4      09:55:24.7747,09:55:24.95,09:55:25.001,09:55:2...
# 5                  03:33:35.99,03:33:35.990,03:33:36.288
# 6                   01:36:23.85,01:36:23.851,01:36:23.87
# 7                               22:18:17.60,22:18:17.599
# 8                    22:23:08.3,22:23:08.26,22:23:08.261
# 9      13:30:05.1055,13:30:05.12,13:30:05.119,13:30:0...
# 10                              01:36:48.16,01:36:48.161
# 11                              20:23:36.26,20:23:36.259
# 12     10:43:53.735,10:43:53.752,10:43:53.76,10:43:53...
# 13                  22:16:09.40,22:16:10.00,22:16:10.001
# 14                  01:24:46.19,01:24:46.15,01:24:46.150
# 15                  09:55:42.12,09:55:42.139,09:55:42.14
# 16     04:41:27.04,04:41:27.168,04:41:27.13,04:41:27....
# 17      15:21:33.12,15:21:33.36,15:21:32.21,15:21:32.210
# 18                  10:46:46.01,10:46:46.030,10:46:46.03
# 20                              04:20:01.41,04:20:01.416
# 21                  14:22:21.03,14:22:21.12,14:22:21.060
# 22                  09:42:53.33,09:42:53.28,09:42:53.330
# 23                  11:33:41.57,11:33:41.550,11:33:41.52
# 25                              00:55:03.33,00:55:03.328
# 26                              10:18:19.310,10:18:19.31
# 27                              07:36:15.76,07:36:15.761
# 28                              13:34:45.492,13:34:45.49
# 29     15:51:12.12,15:51:12.083,15:51:12,15:51:12.24,...
# 30                  16:40:16.200,16:40:16.20,16:40:16.08
# 32                  10:23:56.99,10:23:57.27,10:23:56.990
# 57702                                               0.52  3060.0000     Ia?
# 57703                                                0.5  2900.0000     Ia?
# 57709                                               0.52  3060.0000     Ia?
# 57714                                               0.34  1850.0000     Ia?
# 57719                                        0.422,0.422  2385.0000     IIn
# 57767                                               0.48  2780.0000     Ia?
# 57768                                               0.56  3340.0000     Ia?
# 57774                                               0.62  3780.0000     Ia?
# 57778                                               0.58  3490.0000     Ia?
# 57812                                                0.4  2200.0000     Ia?
# 57842                                        0.146,0.146   714.8000    II P
# 63595                                                NaN     0.0025      Ia
# 63607                                                NaN     0.0010      CC
#
# [18207 rows x 9 columns]

# %% [markdown]
# I will have to iterate through the rows, since some coords have multiple entries, and some dates are bad

# %%
x = []
y = []
z = []
t = []

log10lum = []
name = []
host = []
tpe = []

#for datetime
fmt = '%Y/%m/%d'

N = 1e10
for index, row in df.iterrows():
    bad = False
    
    #there are still some dates that cause errors (e.g., 185/12/07/)
    date = str(row['Disc. Date'])
    pos = date.find(',')
    fmt0 = fmt
    if (pos != -1):    
        date = row['Disc. Date'][0:pos]
    pos1 = date.find('/')
    pos2 = date.rfind('/')
    if (pos1 == -1):
        fmt0 = '%Y'
    if (pos1 != -1 and pos2 == pos1):
        fmt0 = '%Y/%m/'
    if (fmt0 == fmt):
        val1 = int(date[0:pos1])
        if (val1 <= 12):
            fmt0 = '%m/%d/%Y'
        if (val1 > 12 and val1 < 1800):
            bad = True

    if (not bad):
        dt = datetime.datetime.strptime(date, fmt0) 
        t.append(dt.year + dt.month/12. + dt.day/365.24)
        
        ra = row['R.A.']
        pos = str(ra).find(',')
        if (pos != -1):    
            ra = row['R.A.'][0:pos]

        dec = row['Dec.']
        pos = str(dec).find(',')
        if (pos != -1):    
            dec = row['Dec.'][0:pos]

        d = row['dL (Mpc)']*units.Mpc
        #convert to comoving distance
        cosmoz = Distance(d).z
        
        c1 = SkyCoord(ra, dec, unit=(units.hourangle, units.deg), distance=WMAP9.comoving_distance(cosmoz)).galactic.cartesian

        x.append(c1.x.to(units.Mpc).value)
        y.append(c1.y.to(units.Mpc).value)
        z.append(c1.z.to(units.Mpc).value)

        log10lum.append(0.4*(4.74 - row['Mmax']))

        name.append(row['Name'])
        host.append(row['Host Name'])
        tpe.append(row['Type'])
        
    if (index > N):
        break
# Out:
# WARNING: IllegalSecondWarning: 'second' was found  to be '60.0', which is not in range [0,60). Treating as 0 sec, +1 min [astropy.coordinates.angle_utilities]

# %%
print(min(t), max(t))
f, (ax1, ax2) = plt.subplots(1,2, figsize=(10, 5))
_ = ax1.hist(t,bins=100)
_ = ax2.hist(log10lum,bins=100)
# Out:
# 1885.7132114043734 2019.6748804439092

# %% [markdown]
# ### Write this to a new csv file

# %%
print(len(name), len(host), len(tpe), len(x), len(y), len(z), len(t))
data = {'name':np.array(name),
        'host':np.array(host),
        'type':np.array(tpe),
        'x':np.array(x),
        'y':np.array(y),
        'z':np.array(z),
        't':np.array(t),
        'log10lum':np.array(log10lum)}
pd.DataFrame(data).to_csv('OpenSNCatConverted.csv', index=False)
# Out:
# 18201 18201 18201 18201 18201 18201 18201
